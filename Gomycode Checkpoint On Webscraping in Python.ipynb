# %% [markdown]
# ### What You're Aiming For
#
# - Scraping text from Wikipedia website using Beautiful Soup
#
#
# ##### Instructions
#
# - After watching this video below, you will be able to:
#
# ➡️ https://www.youtube.com/watch?v=YY5skv756pc
#
# - 1.1) Write a function to Get and parse html content from a Wikipedia page
#
# - 1.2) Write a function to Extract article title
#
# - 1.3) Write a function to Extract article text for each paragraph with their respective headings. Map those headings to their respective paragraphs in the dictionary.
#
# - 1.4) Write a function to collect every link that redirects to another Wikipedia page
#
# - 1.5) Wrap all the previous functions into a single function that takes as parameters a Wikipedia link
#
# - 1.6) Test the last function on a Wikipedia page of your choice

# %%
import numpy as np
import pandas as pd 
import requests
from bs4 import BeautifulSoup as bs

# %%
web = 'https://en.wikipedia.org/wiki/Demographics_of_Africa'

res = requests.get(web)

if res.status_code == 200:
    print('Successfully Fetched')
else:
    print('Unsuccessful')
# Out:
# Successfully Fetched

# %%
soup = bs(res.content, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Demographics of Africa - Wikipedia\n  </title>\n  <script>\n   (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":[\n"",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"2139566c-4257-45e6-a3e5-32f75ffaaa74","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Demographics_of_Africa","wgTitle":"Demographics of Africa","wgCurRevisionId":1228381344,"wgRevisionId":1228381344,"wgArticleId":6020545,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using the Graph extension","Pages with disabled graphs","Webarchive template wayback links","CS1 maint: others","CS1: long volume value","CS1 maint: location missing publisher","CS1 errors: missing periodical","Use dmy dates from March 2018","Articles with short description","Short description is different from Wikidata","Pages using multiple image with auto scaled images","All articles with unsourced statements",\n"Articles with unsourced statements from February 2021","Commons category link is on Wikidata","Demographics of Africa","Demographics by continent"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Demographics_of_Africa","wgRelevantArticleId":6020545,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":70000,"wgULSCurrentAutonym":"English","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,\n"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q3037005","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","bran ...

# %%
tables = soup.find_all('table')

table_2 = tables[5]
table_2.prettify()
# Out:
# '<table class="wikitable sortable" style="text-align:right">\n <tbody>\n  <tr>\n   <th>\n   </th>\n   <th style="width:80pt;">\n    Mid-year population (thousands)\n   </th>\n   <th style="width:80pt;">\n    Live births (thousands)\n   </th>\n   <th style="width:80pt;">\n    Deaths (thousands)\n   </th>\n   <th style="width:80pt;">\n    Natural change (thousands)\n   </th>\n   <th style="width:80pt;">\n    Crude birth rate (per 1000)\n   </th>\n   <th style="width:80pt;">\n    Crude death rate (per 1000)\n   </th>\n   <th style="width:80pt;">\n    Natural change (per 1000)\n   </th>\n   <th style="width:80pt;">\n    Crude migration change (per 1000)\n   </th>\n   <th style="width:80pt;">\n    <a href="/wiki/Total_fertility_rate" title="Total fertility rate">\n     Total fertility rate\n    </a>\n    (TFR)\n   </th>\n   <th style="width:80pt;">\n    <a href="/wiki/Infant_mortality" title="Infant mortality">\n     Infant mortality\n    </a>\n    (per 1000 live births)\n   </th>\n   <th style="width:80pt;">\n    <a href="/wiki/Life_expectancy" title="Life expectancy">\n     Life expectancy\n    </a>\n    (in years)\n   </th>\n  </tr>\n  <tr>\n   <td>\n    1950\n   </td>\n   <td>\n    227 549\n   </td>\n   <td>\n    10 949\n   </td>\n   <td>\n    6 063\n   </td>\n   <td>\n    4 886\n   </td>\n   <td>\n    48.1\n   </td>\n   <td>\n    26.6\n   </td>\n   <td>\n    21.5\n   </td>\n   <td>\n    0.2\n   </td>\n   <td>\n    6.59\n   </td>\n   <td>\n    186.6\n   </td>\n   <td>\n    37.62\n   </td>\n  </tr>\n  <tr>\n   <td>\n    1951\n   </td>\n   <td>\n    232 484\n   </td>\n   <td>\n    11 200\n   </td>\n   <td>\n    6 132\n   </td>\n   <td>\n    5 068\n   </td>\n   <td style="color:blue">\n    48.2\n   </td>\n   <td>\n    26.4\n   </td>\n   <td>\n    21.8\n   </td>\n   <td>\n    0.1\n   </td>\n   <td>\n    6.59\n   </td>\n   <td>\n    184.5\n   </td>\n   <td>\n    37.93\n   </td>\n  </tr>\n  <tr>\n   <td>\n    1952\n   </td>\n   <td>\n    237 586\n   </td>\n   <td>\n    11 448\n   </td>\n   <td>\n    6 155\n   </td>\n   <td>\n    5 293\n   </td>\n   <td>\n    48.2\n   </td>\n   <td>\n    25.9\n   </td>\n   <td>\n    22.3\n   </td>\n   <td>\n    -0.2\n   </td>\n   <td>\n    6.60\n   </td>\n   <td>\n    181.3\n   </td>\n   <td>\n    38.44\n   </td>\n  </tr>\n  <tr>\n   <td>\n    1953\n   </td>\n   <td>\n    242 837\n   </td>\n   <td>\n    11 708\n   </td>\n   <td>\n    6 188\n   </td>\n   <td>\n    5 520\n   </td>\n   <td>\n    48.2\n   </td>\n   <td>\n    25.5\n   </td>\n   <td>\n    22.7\n   </td>\n   <td>\n    -0.4\n   </td>\n   <td>\n    6.61\n   </td>\n   <td>\n    178.0\n   </td>\n   <td>\n    38.92\n   </td>\n  </tr>\n  <tr>\n   <td>\n    1954\n   </td>\n   <td>\n    248 245\n   </td>\n   <td>\n    11 941\n   </td>\n   <td>\n    6 234\n   </td>\n   <td>\n    5 708\n   </td>\n   <td>\n    48.1\n   </td>\n   <td>\n    25.1\n   </td>\n   <td>\n    23.0\n   </td>\n   <td>\n    -0.4\n   </td>\n   <td>\n    6.61\n   </td>\n   <td>\n    174.7\n   </td>\n   <td>\n    39.30\n   </td>\n  </tr>\n  <tr>\n   <td>\n    1955\n   </td>\n   <td>\n    253 848\n   </td>\n   <td>\n    12 190\n   </td>\n   <td>\n    6 258\n   </td>\n   <td>\n    5 933\n   </td>\n   <td>\n    48.0\n   </td>\n   <td>\n    24.6\n   </td>\n   <td>\n    23.4\n   </td>\n   <td>\n    -0.6\n   </td>\n   <td>\n    6.62\n   </td>\n   <td>\n    171.5\n   </td>\n   <td>\n    39.80\n   </td>\n  </tr>\n  <tr>\n   <td>\n    1956\n   </td>\n   <td>\n    259 631\n   </td>\n   <td>\n    12 453\n   </td>\n   <td>\n    6 312\n   </td>\n   <td>\n    6 141\n   </td>\n   <td>\n    47.9\n   </td>\n   <td>\n    24.3\n   </td>\n   <td>\n    23.6\n   </td>\n   <td>\n    -0.9\n   </td>\n   <td>\n    6.63\n   </td>\n   <td>\n    168.9\n   </td>\n   <td>\n    40.17\n   </td>\n  </tr>\n  <tr>\n   <td>\n    1957\n   </td>\n   <td>\n    265 515\n   </td>\n   <td>\n    12 717\n   </td>\n   <td>\n    6 490\n   </td>\n   <td>\n    6 227\n   </td>\n   <td>\n    47.9\n   </td>\n   <td>\n    24.4\n   </td ...

# %%
demographic_of_africa = []

# %%
africa = table_2.find_all('tr')
for row in africa[1:]:
    column = row.find_all("td")
    if len(column) >= 11:
        Index = column[0].get_text(strip = True)
        Mid_year_population = column[1].get_text(strip = True)
        Live_births = column[2].get_text(strip = True)
        Deaths = column[3].get_text(strip = True)
        Natural_change = column[4].get_text(strip = True)
        Crude_birth_rate = column[5].get_text(strip = True)
        Crude_death_rate = column[6].get_text(strip = True)
        Natural_change_ = column[7].get_text(strip = True)
        Crude_migration_change = column[8].get_text(strip = True)
        Total_fertility_rate = column[9].get_text(strip = True)
        infant_mortality = column[10].get_text(strip = True)
        life_expentancy = column[11].get_text(strip = True)
        
        demographic_of_africa.append({
            "Index": Index,
            "Mid-year population": Mid_year_population,
            "Live_births": Live_births,
            "Deaths": Deaths,
            "Natural_change": Natural_change,
            "Crude_birth_rate": Crude_birth_rate,
            "Crude_death_rate": Crude_death_rate,
            "Natural_change_(per1000)": Natural_change,
            "Crude_migration_change":Crude_migration_change,
            "Total_fertility_rate":Total_fertility_rate,
            "infant_mortality":infant_mortality,
            "life_expentancy_(inyears)":life_expentancy
        })
    else:
        print("Failed to fetch")

# %%
demographic_of_africa
# Out:
# [{'Index': '1950',
#   'Mid-year population': '227 549',
#   'Live_births': '10 949',
#   'Deaths': '6 063',
#   'Natural_change': '4 886',
#   'Crude_birth_rate': '48.1',
#   'Crude_death_rate': '26.6',
#   'Natural_change_(per1000)': '4 886',
#   'Crude_migration_change': '0.2',
#   'Total_fertility_rate': '6.59',
#   'infant_mortality': '186.6',
#   'life_expentancy_(inyears)': '37.62'},
#  {'Index': '1951',
#   'Mid-year population': '232 484',
#   'Live_births': '11 200',
#   'Deaths': '6 132',
#   'Natural_change': '5 068',
#   'Crude_birth_rate': '48.2',
#   'Crude_death_rate': '26.4',
#   'Natural_change_(per1000)': '5 068',
#   'Crude_migration_change': '0.1',
#   'Total_fertility_rate': '6.59',
#   'infant_mortality': '184.5',
#   'life_expentancy_(inyears)': '37.93'},
#  {'Index': '1952',
#   'Mid-year population': '237 586',
#   'Live_births': '11 448',
#   'Deaths': '6 155',
#   'Natural_change': '5 293',
#   'Crude_birth_rate': '48.2',
#   'Crude_death_rate': '25.9',
#   'Natural_change_(per1000)': '5 293',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '6.60',
#   'infant_mortality': '181.3',
#   'life_expentancy_(inyears)': '38.44'},
#  {'Index': '1953',
#   'Mid-year population': '242 837',
#   'Live_births': '11 708',
#   'Deaths': '6 188',
#   'Natural_change': '5 520',
#   'Crude_birth_rate': '48.2',
#   'Crude_death_rate': '25.5',
#   'Natural_change_(per1000)': '5 520',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '6.61',
#   'infant_mortality': '178.0',
#   'life_expentancy_(inyears)': '38.92'},
#  {'Index': '1954',
#   'Mid-year population': '248 245',
#   'Live_births': '11 941',
#   'Deaths': '6 234',
#   'Natural_change': '5 708',
#   'Crude_birth_rate': '48.1',
#   'Crude_death_rate': '25.1',
#   'Natural_change_(per1000)': '5 708',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '6.61',
#   'infant_mortality': '174.7',
#   'life_expentancy_(inyears)': '39.30'},
#  {'Index': '1955',
#   'Mid-year population': '253 848',
#   'Live_births': '12 190',
#   'Deaths': '6 258',
#   'Natural_change': '5 933',
#   'Crude_birth_rate': '48.0',
#   'Crude_death_rate': '24.6',
#   'Natural_change_(per1000)': '5 933',
#   'Crude_migration_change': '-0.6',
#   'Total_fertility_rate': '6.62',
#   'infant_mortality': '171.5',
#   'life_expentancy_(inyears)': '39.80'},
#  {'Index': '1956',
#   'Mid-year population': '259 631',
#   'Live_births': '12 453',
#   'Deaths': '6 312',
#   'Natural_change': '6 141',
#   'Crude_birth_rate': '47.9',
#   'Crude_death_rate': '24.3',
#   'Natural_change_(per1000)': '6 141',
#   'Crude_migration_change': '-0.9',
#   'Total_fertility_rate': '6.63',
#   'infant_mortality': '168.9',
#   'life_expentancy_(inyears)': '40.17'},
#  {'Index': '1957',
#   'Mid-year population': '265 515',
#   'Live_births': '12 717',
#   'Deaths': '6 490',
#   'Natural_change': '6 227',
#   'Crude_birth_rate': '47.9',
#   'Crude_death_rate': '24.4',
#   'Natural_change_(per1000)': '6 227',
#   'Crude_migration_change': '-1.1',
#   'Total_fertility_rate': '6.64',
#   'infant_mortality': '169.1',
#   'life_expentancy_(inyears)': '40.01'},
#  {'Index': '1958',
#   'Mid-year population': '271 430',
#   'Live_births': '12 982',
#   'Deaths': '6 556',
#   'Natural_change': '6 427',
#   'Crude_birth_rate': '47.8',
#   'Crude_death_rate': '24.1',
#   'Natural_change_(per1000)': '6 427',
#   'Crude_migration_change': '-0.8',
#   'Total_fertility_rate': '6.65',
#   'infant_mortality': '166.5',
#   'life_expentancy_(inyears)': '40.30'},
#  {'Index': '1959',
#   'Mid-year population': '277 648',
#   'Live_births': '13 244',
#   'Deaths': '6 459',
#   'Natural_change': '6 785',
#   'Crude_birth_rate': '47.7',
#   'Crude_death_rate': '23.2',
#   'Natural_change_(per1000)': '6 785',
#   'Crude_migration_change': '-0.5',
#   'Total_fertility_rate': '6.66',
#   'infant_mortality': '161.0',
#   'life_expentancy_(inyears)': '41.28'},
#  {'Index': '1960',
#   'Mid-year population': '284 288',
#   'Live_births': '13 538',
#   'Deaths': '6 553',
#   'Natural_change': '6 985',
#   'Crude_birth_rate': '47.6',
#   'Crude_death_rate': '23.0',
#   'Natural_change_(per1000)': '6 985',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '6.67',
#   'infant_mortality': '158.6',
#   'life_expentancy_(inyears)': '41.48'},
#  {'Index': '1961',
#   'Mid-year population': '291 178',
#   'Live_births': '13 864',
#   'Deaths': '6 612',
#   'Natural_change': '7 251',
#   'Crude_birth_rate': '47.6',
#   'Crude_death_rate': '22.7',
#   'Natural_change_(per1000)': '7 251',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '6.69',
#   'infant_mortality': '156.2',
#   'life_expentancy_(inyears)': '41.87'},
#  {'Index': '1962',
#   'Mid-year population': '298 334',
#   'Live_births': '14 205',
#   'Deaths': '6 670',
#   'Natural_change': '7 535',
#   'Crude_birth_rate': '47.6',
#   'Crude_death_rate': '22.3',
#   'Natural_change_(per1000)': '7 535',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '6.71',
#   'infant_mortality': '153.9',
#   'life_expentancy_(inyears)': '42.32'},
#  {'Index': '1963',
#   'Mid-year population': '305 755',
#   'Live_births': '14 531',
#   'Deaths': '6 724',
#   'Natural_change': '7 808',
#   'Crude_birth_rate': '47.5',
#   'Crude_death_rate': '22.0',
#   'Natural_change_(per1000)': '7 808',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '6.71',
#   'infant_mortality': '151.6',
#   'life_expentancy_(inyears)': '42.78'},
#  {'Index': '1964',
#   'Mid-year population': '313 466',
#   'Live_births': '14 864',
#   'Deaths': '6 773',
#   'Natural_change': '8 090',
#   'Crude_birth_rate': '47.4',
#   'Crude_death_rate': '21.6',
#   'Natural_change_(per1000)': '8 090',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '6.72',
#   'infant_mortality': '149.3',
#   'life_expentancy_(inyears)': '43.25'},
#  {'Index': '1965',
#   'Mid-year population': '321 447',
#   'Live_births': '15 202',
#   'Deaths': '6 887',
#   'Natural_change': '8 315',
#   'Crude_birth_rate': '47.3',
#   'Crude_death_rate': '21.4',
#   'Natural_change_(per1000)': '8 315',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '6.71',
#   'infant_mortality': '147.6',
#   'life_expentancy_(inyears)': '43.44'},
#  {'Index': '1966',
#   'Mid-year population': '329 658',
#   'Live_births': '15 559',
#   'Deaths': '7 054',
#   'Natural_change': '8 505',
#   'Crude_birth_rate': '47.2',
#   'Crude_death_rate': '21.4',
#   'Natural_change_(per1000)': '8 505',
#   'Crude_migration_change': '0',
#   'Total_fertility_rate': '6.72',
#   'infant_mortality': '146.8',
#   'life_expentancy_(inyears)': '43.43'},
#  {'Index': '1967',
#   'Mid-year population': '338 160',
#   'Live_births': '15 920',
#   'Deaths': '7 156',
#   'Natural_change': '8 764',
#   'Crude_birth_rate': '47.1',
#   'Crude_death_rate': '21.2',
#   'Natural_change_(per1000)': '8 764',
#   'Crude_migration_change': '0.2',
#   'Total_fertility_rate': '6.72',
#   'infant_mortality': '144.4',
#   'life_expentancy_(inyears)': '43.65'},
#  {'Index': '1968',
#   'Mid-year population': '346 980',
#   'Live_births': '16 292',
#   'Deaths': '7 210',
#   'Natural_change': '9 082',
#   'Crude_birth_rate': '46.9',
#   'Crude_death_rate': '20.8',
#   'Natural_change_(per1000)': '9 082',
#   'Crude_migration_change': '0',
#   'Total_fertility_rate': '6.72',
#   'infant_mortality': '142.6',
#   'life_expentancy_(inyears)': '44.10'},
#  {'Index': '1969',
#   'Mid-year population': '356 070',
#   'Live_births': '16 689',
#   'Deaths': '7 328',
#   'Natural_change': '9 361',
#   'Crude_birth_rate': '46.9',
#   'Crude_death_rate': '20.6',
#   'Natural_change_(per1000)': '9 361',
#   'Crude_migration_change': '0',
#   'Total_fertility_rate': '6.71',
#   'infant_mortality': '141.0',
#   'life_expentancy_(inyears)': '44.32'},
#  {'Index': '1970',
#   'Mid-year population': '365 450',
#   'Live_births': '17 086',
#   'Deaths': '7 384',
#   'Natural_change': '9 702',
#   'Crude_birth_rate': '46.7',
#   'Crude_death_rate': '20.2',
#   'Natural_change_(per1000)': '9 702',
#   'Crude_migration_change': '-0.1',
#   'Total_fertility_rate': '6.71',
#   'infant_mortality': '139.2',
#   'life_expentancy_(inyears)': '44.78'},
#  {'Index': '1971',
#   'Mid-year population': '375 086',
#   'Live_births': '17 528',
#   'Deaths': '7 423',
#   'Natural_change': '10 105',
#   'Crude_birth_rate': '46.7',
#   'Crude_death_rate': '19.8',
#   'Natural_change_(per1000)': '10 105',
#   'Crude_migration_change': '-0.7',
#   'Total_fertility_rate': '6.71',
#   'infant_mortality': '137.1',
#   'life_expentancy_(inyears)': '45.32'},
#  {'Index': '1972',
#   'Mid-year population': '384 930',
#   'Live_births': '17 939',
#   'Deaths': '7 572',
#   'Natural_change': '10 367',
#   'Crude_birth_rate': '46.6',
#   'Crude_death_rate': '19.7',
#   'Natural_change_(per1000)': '10 367',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '6.71',
#   'infant_mortality': '135.6',
#   'life_expentancy_(inyears)': '45.41'},
#  {'Index': '1973',
#   'Mid-year population': '395 212',
#   'Live_births': '18 341',
#   'Deaths': '7 547',
#   'Natural_change': '10 794',
#   'Crude_birth_rate': '46.4',
#   'Crude_death_rate': '19.1',
#   'Natural_change_(per1000)': '10 794',
#   'Crude_migration_change': '0.2',
#   'Total_fertility_rate': '6.70',
#   'infant_mortality': '133.1',
#   'life_expentancy_(inyears)': '46.15'},
#  {'Index': '1974',
#   'Mid-year population': '406 069',
#   'Live_births': '18 817',
#   'Deaths': '7 658',
#   'Natural_change': '11 160',
#   'Crude_birth_rate': '46.3',
#   'Crude_death_rate': '18.9',
#   'Natural_change_(per1000)': '11 160',
#   'Crude_migration_change': '0.8',
#   'Total_fertility_rate': '6.70',
#   'infant_mortality': '132.0',
#   'life_expentancy_(inyears)': '46.46'},
#  {'Index': '1975',
#   'Mid-year population': '417 557',
#   'Live_births': '19 324',
#   'Deaths': '7 724',
#   'Natural_change': '11 600',
#   'Crude_birth_rate': '46.3',
#   'Crude_death_rate': '18.5',
#   'Natural_change_(per1000)': '11 600',
#   'Crude_migration_change': '1.0',
#   'Total_fertility_rate': '6.69',
#   'infant_mortality': '129.6',
#   'life_expentancy_(inyears)': '46.90'},
#  {'Index': '1976',
#   'Mid-year population': '429 573',
#   'Live_births': '19 818',
#   'Deaths': '7 710',
#   'Natural_change': '12 109',
#   'Crude_birth_rate': '46.1',
#   'Crude_death_rate': '17.9',
#   'Natural_change_(per1000)': '12 109',
#   'Crude_migration_change': '0',
#   'Total_fertility_rate': '6.68',
#   'infant_mortality': '126.1',
#   'life_expentancy_(inyears)': '47.64'},
#  {'Index': '1977',
#   'Mid-year population': '441 701',
#   'Live_births': '20 340',
#   'Deaths': '7 764',
#   'Natural_change': '12 576',
#   'Crude_birth_rate': '46.0',
#   'Crude_death_rate': '17.6',
#   'Natural_change_(per1000)': '12 576',
#   'Crude_migration_change': '0.4',
#   'Total_fertility_rate': '6.67',
#   'infant_mortality': '123.6',
#   'life_expentancy_(inyears)': '48.16'},
#  {'Index': '1978',
#   'Mid-year population': '454 463',
#   'Live_births': '20 861',
#   'Deaths': '7 841',
#   'Natural_change': '13 019',
#   'Crude_birth_rate': '45.9',
#   'Crude_death_rate': '17.3',
#   'Natural_change_(per1000)': '13 019',
#   'Crude_migration_change': '1.0',
#   'Total_fertility_rate': '6.66',
#   'infant_mortality': '121.3',
#   'life_expentancy_(inyears)': '48.57'},
#  {'Index': '1979',
#   'Mid-year population': '467 976',
#   'Live_births': '21 448',
#   'Deaths': '7 901',
#   'Natural_change': '13 546',
#   'Crude_birth_rate': '45.8',
#   'Crude_death_rate': '16.9',
#   'Natural_change_(per1000)': '13 546',
#   'Crude_migration_change': '0.1',
#   'Total_fertility_rate': '6.64',
#   'infant_mortality': '118.7',
#   'life_expentancy_(inyears)': '49.10'},
#  {'Index': '1980',
#   'Mid-year population': '481 543',
#   'Live_births': '21 984',
#   'Deaths': '7 986',
#   'Natural_change': '13 998',
#   'Crude_birth_rate': '45.6',
#   'Crude_death_rate': '16.6',
#   'Natural_change_(per1000)': '13 998',
#   'Crude_migration_change': '0.3',
#   'Total_fertility_rate': '6.60',
#   'infant_mortality': '116.4',
#   'life_expentancy_(inyears)': '49.51'},
#  {'Index': '1981',
#   'Mid-year population': '495 655',
#   'Live_births': '22 490',
#   'Deaths': '8 055',
#   'Natural_change': '14 435',
#   'Crude_birth_rate': '45.4',
#   'Crude_death_rate': '16.3',
#   'Natural_change_(per1000)': '14 435',
#   'Crude_migration_change': '0.9',
#   'Total_fertility_rate': '6.56',
#   'infant_mortality': '114.2',
#   'life_expentancy_(inyears)': '49.91'},
#  {'Index': '1982',
#   'Mid-year population': '510 540',
#   'Live_births': '23 060',
#   'Deaths': '8 146',
#   'Natural_change': '14 914',
#   'Crude_birth_rate': '45.2',
#   'Crude_death_rate': '16.0',
#   'Natural_change_(per1000)': '14 914',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '6.51',
#   'infant_mortality': '111.7',
#   'life_expentancy_(inyears)': '50.28'},
#  {'Index': '1983',
#   'Mid-year population': '525 335',
#   'Live_births': '23 656',
#   'Deaths': '8 633',
#   'Natural_change': '15 023',
#   'Crude_birth_rate': '45.0',
#   'Crude_death_rate': '16.4',
#   'Natural_change_(per1000)': '15 023',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '6.47',
#   'infant_mortality': '114.1',
#   'life_expentancy_(inyears)': '49.55'},
#  {'Index': '1984',
#   'Mid-year population': '540 183',
#   'Live_births': '24 153',
#   'Deaths': '8 774',
#   'Natural_change': '15 379',
#   'Crude_birth_rate': '44.7',
#   'Crude_death_rate': '16.2',
#   'Natural_change_(per1000)': '15 379',
#   'Crude_migration_change': '0.1',
#   'Total_fertility_rate': '6.41',
#   'infant_mortality': '112.0',
#   'life_expentancy_(inyears)': '49.71'},
#  {'Index': '1985',
#   'Mid-year population': '555 653',
#   'Live_births': '24 673',
#   'Deaths': '8 850',
#   'Natural_change': '15 823',
#   'Crude_birth_rate': '44.4',
#   'Crude_death_rate': '15.9',
#   'Natural_change_(per1000)': '15 823',
#   'Crude_migration_change': '0.3',
#   'Total_fertility_rate': '6.34',
#   'infant_mortality': '109.8',
#   'life_expentancy_(inyears)': '50.09'},
#  {'Index': '1986',
#   'Mid-year population': '571 646',
#   'Live_births': '25 161',
#   'Deaths': '8 891',
#   'Natural_change': '16 270',
#   'Crude_birth_rate': '44.0',
#   'Crude_death_rate': '15.6',
#   'Natural_change_(per1000)': '16 270',
#   'Crude_migration_change': '0.2',
#   'Total_fertility_rate': '6.26',
#   'infant_mortality': '107.0',
#   'life_expentancy_(inyears)': '50.55'},
#  {'Index': '1987',
#   'Mid-year population': '588 080',
#   'Live_births': '25 632',
#   'Deaths': '8 944',
#   'Natural_change': '16 689',
#   'Crude_birth_rate': '43.6',
#   'Crude_death_rate': '15.2',
#   'Natural_change_(per1000)': '16 689',
#   'Crude_migration_change': '-0.5',
#   'Total_fertility_rate': '6.20',
#   'infant_mortality': '103.0',
#   'life_expentancy_(inyears)': '50.90'},
#  {'Index': '1988',
#   'Mid-year population': '604 511',
#   'Live_births': '26 013',
#   'Deaths': '9 360',
#   'Natural_change': '16 653',
#   'Crude_birth_rate': '43.0',
#   'Crude_death_rate': '15.5',
#   'Natural_change_(per1000)': '16 653',
#   'Crude_migration_change': '0.1',
#   'Total_fertility_rate': '6.11',
#   'infant_mortality': '105.1',
#   'life_expentancy_(inyears)': '50.43'},
#  {'Index': '1989',
#   'Mid-year population': '621 168',
#   'Live_births': '26 405',
#   'Deaths': '9 072',
#   'Natural_change': '17 333',
#   'Crude_birth_rate': '42.5',
#   'Crude_death_rate': '14.6',
#   'Natural_change_(per1000)': '17 333',
#   'Crude_migration_change': '-0.5',
#   'Total_fertility_rate': '6.02',
#   'infant_mortality': '100.5',
#   'life_expentancy_(inyears)': '51.68'},
#  {'Index': '1990',
#   'Mid-year population': '638 157',
#   'Live_births': '26 758',
#   'Deaths': '9 278',
#   'Natural_change': '17 480',
#   'Crude_birth_rate': '41.9',
#   'Crude_death_rate': '14.5',
#   'Natural_change_(per1000)': '17 480',
#   'Crude_migration_change': '-0.9',
#   'Total_fertility_rate': '5.91',
#   'infant_mortality': '99.8',
#   'life_expentancy_(inyears)': '51.65'},
#  {'Index': '1991',
#   'Mid-year population': '655 040',
#   'Live_births': '27 202',
#   'Deaths': '9 556',
#   'Natural_change': '17 646',
#   'Crude_birth_rate': '41.5',
#   'Crude_death_rate': '14.6',
#   'Natural_change_(per1000)': '17 646',
#   'Crude_migration_change': '-1.1',
#   'Total_fertility_rate': '5.83',
#   'infant_mortality': '100.4',
#   'life_expentancy_(inyears)': '51.49'},
#  {'Index': '1992',
#   'Mid-year population': '671 932',
#   'Live_births': '27 649',
#   'Deaths': '9 850',
#   'Natural_change': '17 798',
#   'Crude_birth_rate': '41.1',
#   'Crude_death_rate': '14.6',
#   'Natural_change_(per1000)': '17 798',
#   'Crude_migration_change': '-0.9',
#   'Total_fertility_rate': '5.76',
#   'infant_mortality': '99.7',
#   'life_expentancy_(inyears)': '51.24'},
#  {'Index': '1993',
#   'Mid-year population': '689 140',
#   'Live_births': '28 063',
#   'Deaths': '9 907',
#   'Natural_change': '18 156',
#   'Crude_birth_rate': '40.7',
#   'Crude_death_rate': '14.4',
#   'Natural_change_(per1000)': '18 156',
#   'Crude_migration_change': '-1.1',
#   'Total_fertility_rate': '5.67',
#   'infant_mortality': '97.4',
#   'life_expentancy_(inyears)': '51.55'},
#  {'Index': '1994',
#   'Mid-year population': '706 488',
#   'Live_births': '28 449',
#   'Deaths': '10 476',
#   'Natural_change': '17 973',
#   'Crude_birth_rate': '40.2',
#   'Crude_death_rate': '14.8',
#   'Natural_change_(per1000)': '17 973',
#   'Crude_migration_change': '-0.1',
#   'Total_fertility_rate': '5.59',
#   'infant_mortality': '96.5',
#   'life_expentancy_(inyears)': '50.52'},
#  {'Index': '1995',
#   'Mid-year population': '724 332',
#   'Live_births': '28 953',
#   'Deaths': '10 080',
#   'Natural_change': '18 873',
#   'Crude_birth_rate': '40.0',
#   'Crude_death_rate': '13.9',
#   'Natural_change_(per1000)': '18 873',
#   'Crude_migration_change': '-0.6',
#   'Total_fertility_rate': '5.51',
#   'infant_mortality': '95.0',
#   'life_expentancy_(inyears)': '52.12'},
#  {'Index': '1996',
#   'Mid-year population': '742 765',
#   'Live_births': '29 395',
#   'Deaths': '10 282',
#   'Natural_change': '19 113',
#   'Crude_birth_rate': '39.6',
#   'Crude_death_rate': '13.8',
#   'Natural_change_(per1000)': '19 113',
#   'Crude_migration_change': '-0.8',
#   'Total_fertility_rate': '5.42',
#   'infant_mortality': '94.0',
#   'life_expentancy_(inyears)': '52.13'},
#  {'Index': '1997',
#   'Mid-year population': '761 224',
#   'Live_births': '29 764',
#   'Deaths': '10 413',
#   'Natural_change': '19 351',
#   'Crude_birth_rate': '39.1',
#   'Crude_death_rate': '13.7',
#   'Natural_change_(per1000)': '19 351',
#   'Crude_migration_change': '-0.9',
#   'Total_fertility_rate': '5.34',
#   'infant_mortality': '92.4',
#   'life_expentancy_(inyears)': '52.31'},
#  {'Index': '1998',
#   'Mid-year population': '779 908',
#   'Live_births': '30 212',
#   'Deaths': '10 806',
#   'Natural_change': '19 406',
#   'Crude_birth_rate': '38.7',
#   'Crude_death_rate': '13.8',
#   'Natural_change_(per1000)': '19 406',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '5.27',
#   'infant_mortality': '91.7',
#   'life_expentancy_(inyears)': '51.90'},
#  {'Index': '1999',
#   'Mid-year population': '799 099',
#   'Live_births': '30 849',
#   'Deaths': '10 633',
#   'Natural_change': '20 216',
#   'Crude_birth_rate': '38.6',
#   'Crude_death_rate': '13.3',
#   'Natural_change_(per1000)': '20 216',
#   'Crude_migration_change': '-0.5',
#   'Total_fertility_rate': '5.22',
#   'infant_mortality': '88.3',
#   'life_expentancy_(inyears)': '52.78'},
#  {'Index': '2000',
#   'Mid-year population': '818 952',
#   'Live_births': '31 448',
#   'Deaths': '10 614',
#   'Natural_change': '20 833',
#   'Crude_birth_rate': '38.4',
#   'Crude_death_rate': '13.0',
#   'Natural_change_(per1000)': '20 833',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '5.18',
#   'infant_mortality': '85.9',
#   'life_expentancy_(inyears)': '53.35'},
#  {'Index': '2001',
#   'Mid-year population': '839 464',
#   'Live_births': '32 119',
#   'Deaths': '10 728',
#   'Natural_change': '21 392',
#   'Crude_birth_rate': '38.2',
#   'Crude_death_rate': '12.8',
#   'Natural_change_(per1000)': '21 392',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '5.14',
#   'infant_mortality': '83.4',
#   'life_expentancy_(inyears)': '53.62'},
#  {'Index': '2002',
#   'Mid-year population': '860 611',
#   'Live_births': '32 750',
#   'Deaths': '10 799',
#   'Natural_change': '21 951',
#   'Crude_birth_rate': '38.0',
#   'Crude_death_rate': '12.5',
#   'Natural_change_(per1000)': '21 951',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '5.10',
#   'infant_mortality': '80.9',
#   'life_expentancy_(inyears)': '54.00'},
#  {'Index': '2003',
#   'Mid-year population': '882 349',
#   'Live_births': '33 422',
#   'Deaths': '10 849',
#   'Natural_change': '22 574',
#   'Crude_birth_rate': '37.9',
#   'Crude_death_rate': '12.3',
#   'Natural_change_(per1000)': '22 574',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '5.06',
#   'infant_mortality': '78.2',
#   'life_expentancy_(inyears)': '54.42'},
#  {'Index': '2004',
#   'Mid-year population': '904 781',
#   'Live_births': '34 130',
#   'Deaths': '10 876',
#   'Natural_change': '23 254',
#   'Crude_birth_rate': '37.7',
#   'Crude_death_rate': '12.0',
#   'Natural_change_(per1000)': '23 254',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '5.02',
#   'infant_mortality': '75.5',
#   'life_expentancy_(inyears)': '54.90'},
#  {'Index': '2005',
#   'Mid-year population': '927 898',
#   'Live_births': '34 950',
#   'Deaths': '10 866',
#   'Natural_change': '24 084',
#   'Crude_birth_rate': '37.6',
#   'Crude_death_rate': '11.7',
#   'Natural_change_(per1000)': '24 084',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '5.00',
#   'infant_mortality': '72.8',
#   'life_expentancy_(inyears)': '55.47'},
#  {'Index': '2006',
#   'Mid-year population': '951 740',
#   'Live_births': '35 735',
#   'Deaths': '10 807',
#   'Natural_change': '24 928',
#   'Crude_birth_rate': '37.5',
#   'Crude_death_rate': '11.3',
#   'Natural_change_(per1000)': '24 928',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '4.97',
#   'infant_mortality': '70.2',
#   'life_expentancy_(inyears)': '56.14'},
#  {'Index': '2007',
#   'Mid-year population': '976 461',
#   'Live_births': '36 540',
#   'Deaths': '10 784',
#   'Natural_change': '25 756',
#   'Crude_birth_rate': '37.4',
#   'Crude_death_rate': '11.0',
#   'Natural_change_(per1000)': '25 756',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '4.95',
#   'infant_mortality': '67.7',
#   'life_expentancy_(inyears)': '56.73'},
#  {'Index': '2008',
#   'Mid-year population': '1 001 981',
#   'Live_births': '37 411',
#   'Deaths': '10 769',
#   'Natural_change': '26 642',
#   'Crude_birth_rate': '37.3',
#   'Crude_death_rate': '10.7',
#   'Natural_change_(per1000)': '26 642',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '4.93',
#   'infant_mortality': '65.3',
#   'life_expentancy_(inyears)': '57.31'},
#  {'Index': '2009',
#   'Mid-year population': '1 028 200',
#   'Live_births': '38 122',
#   'Deaths': '10 679',
#   'Natural_change': '27 443',
#   'Crude_birth_rate': '37.1',
#   'Crude_death_rate': '10.4',
#   'Natural_change_(per1000)': '27 443',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '4.89',
#   'infant_mortality': '62.9',
#   'life_expentancy_(inyears)': '58.02'},
#  {'Index': '2010',
#   'Mid-year population': '1 055 233',
#   'Live_births': '38 920',
#   'Deaths': '10 652',
#   'Natural_change': '28 268',
#   'Crude_birth_rate': '36.9',
#   'Crude_death_rate': '10.1',
#   'Natural_change_(per1000)': '28 268',
#   'Crude_migration_change': '-0.8',
#   'Total_fertility_rate': '4.86',
#   'infant_mortality': '60.9',
#   'life_expentancy_(inyears)': '58.61'},
#  {'Index': '2011',
#   'Mid-year population': '1 082 676',
#   'Live_births': '39 651',
#   'Deaths': '10 594',
#   'Natural_change': '29 057',
#   'Crude_birth_rate': '36.6',
#   'Crude_death_rate': '9.8',
#   'Natural_change_(per1000)': '29 057',
#   'Crude_migration_change': '-0.8',
#   'Total_fertility_rate': '4.82',
#   'infant_mortality': '58.9',
#   'life_expentancy_(inyears)': '59.25'},
#  {'Index': '2012',
#   'Mid-year population': '1 110 797',
#   'Live_births': '40 262',
#   'Deaths': '10 562',
#   'Natural_change': '29 700',
#   'Crude_birth_rate': '36.2',
#   'Crude_death_rate': '9.5',
#   'Natural_change_(per1000)': '29 700',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '4.77',
#   'infant_mortality': '57.0',
#   'life_expentancy_(inyears)': '59.81'},
#  {'Index': '2013',
#   'Mid-year population': '1 140 181',
#   'Live_births': '40 882',
#   'Deaths': '10 569',
#   'Natural_change': '30 313',
#   'Crude_birth_rate': '35.8',
#   'Crude_death_rate': '9.3',
#   'Natural_change_(per1000)': '30 313',
#   'Crude_migration_change': '-0.2',
#   'Total_fertility_rate': '4.72',
#   'infant_mortality': '55.4',
#   'life_expentancy_(inyears)': '60.29'},
#  {'Index': '2014',
#   'Mid-year population': '1 170 299',
#   'Live_births': '41 517',
#   'Deaths': '10 590',
#   'Natural_change': '30 927',
#   'Crude_birth_rate': '35.5',
#   'Crude_death_rate': '9.0',
#   'Natural_change_(per1000)': '30 927',
#   'Crude_migration_change': '-0.1',
#   'Total_fertility_rate': '4.67',
#   'infant_mortality': '53.9',
#   'life_expentancy_(inyears)': '60.75'},
#  {'Index': '2015',
#   'Mid-year population': '1 201 108',
#   'Live_births': '42 128',
#   'Deaths': '10 647',
#   'Natural_change': '31 481',
#   'Crude_birth_rate': '35.1',
#   'Crude_death_rate': '8.9',
#   'Natural_change_(per1000)': '31 481',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '4.63',
#   'infant_mortality': '52.5',
#   'life_expentancy_(inyears)': '61.13'},
#  {'Index': '2016',
#   'Mid-year population': '1 232 112',
#   'Live_births': '42 515',
#   'Deaths': '10 652',
#   'Natural_change': '31 863',
#   'Crude_birth_rate': '34.5',
#   'Crude_death_rate': '8.6',
#   'Natural_change_(per1000)': '31 863',
#   'Crude_migration_change': '-0.5',
#   'Total_fertility_rate': '4.56',
#   'infant_mortality': '51.3',
#   'life_expentancy_(inyears)': '61.59'},
#  {'Index': '2017',
#   'Mid-year population': '1 263 334',
#   'Live_births': '43 102',
#   'Deaths': '10 695',
#   'Natural_change': '32 408',
#   'Crude_birth_rate': '34.1',
#   'Crude_death_rate': '8.5',
#   'Natural_change_(per1000)': '32 408',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '4.52',
#   'infant_mortality': '50.0',
#   'life_expentancy_(inyears)': '61.99'},
#  {'Index': '2018',
#   'Mid-year population': '1 295 265',
#   'Live_births': '43 713',
#   'Deaths': '10 763',
#   'Natural_change': '32 950',
#   'Crude_birth_rate': '33.7',
#   'Crude_death_rate': '8.3',
#   'Natural_change_(per1000)': '32 950',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '4.47',
#   'infant_mortality': '48.8',
#   'life_expentancy_(inyears)': '62.34'},
#  {'Index': '2019',
#   'Mid-year population': '1 327 701',
#   'Live_births': '44 295',
#   'Deaths': '10 841',
#   'Natural_change': '33 454',
#   'Crude_birth_rate': '33.3',
#   'Crude_death_rate': '8.2',
#   'Natural_change_(per1000)': '33 454',
#   'Crude_migration_change': '-0.4',
#   'Total_fertility_rate': '4.42',
#   'infant_mortality': '47.7',
#   'life_expentancy_(inyears)': '62.69'},
#  {'Index': '2020',
#   'Mid-year population': '1 360 677',
#   'Live_births': '44 807',
#   'Deaths': '11 390',
#   'Natural_change': '33 417',
#   'Crude_birth_rate': '32.9',
#   'Crude_death_rate': '8.4',
#   'Natural_change_(per1000)': '33 417',
#   'Crude_migration_change': '-0.3',
#   'Total_fertility_rate': '4.36',
#   'infant_mortality': '46.4',
#   'life_expentancy_(inyears)': '62.23'},
#  {'Index': '2021',
#   'Mid-year population': '1 393 676',
#   'Live_births': '45 369',
#   'Deaths': '12 038',
#   'Natural_change': '33 331',
#   'Crude_birth_rate': '32.5',
#   'Crude_death_rate': '8.6',
#   'Natural_change_(per1000)': '33 331',
#   'Crude_migration_change': '',
#   'Total_fertility_rate': '4.31',
#   'infant_mortality': '45.4',
#   'life_expentancy_(inyears)': '61.66'}]

# %%
demographic_of_africa_df = pd.DataFrame(demographic_of_africa)

# %%
demographic_of_africa_df
# Out:
#    Index Mid-year population Live_births  Deaths Natural_change  \
# 0   1950             227 549      10 949   6 063          4 886
# 1   1951             232 484      11 200   6 132          5 068
# 2   1952             237 586      11 448   6 155          5 293
# 3   1953             242 837      11 708   6 188          5 520
# 4   1954             248 245      11 941   6 234          5 708
# ..   ...                 ...         ...     ...            ...
# 67  2017           1 263 334      43 102  10 695         32 408
# 68  2018           1 295 265      43 713  10 763         32 950
# 69  2019           1 327 701      44 295  10 841         33 454
# 70  2020           1 360 677      44 807  11 390         33 417
# 71  2021           1 393 676      45 369  12 038         33 331
#
#    Crude_birth_rate Crude_death_rate Natural_change_(per1000)  \
# 0              48.1             26.6                    4 886
# 1              48.2             26.4                    5 068
# 2              48.2             25.9                    5 293
# 3              48.2             25.5                    5 520
# 4              48.1             25.1                    5 708
# ..              ...              ...                      ...
# 67             34.1              8.5                   32 408
# 68             33.7              8.3                   32 950
# 69             33.3              8.2                   33 454
# 70             32.9              8.4                   33 417
# 71             32.5              8.6                   33 331
#
#    Crude_migration_change Total_fertility_rate infant_mortality  \
# 0                     0.2                 6.59            186.6
# 1                     0.1                 6.59            184.5
# 2                    -0.2                 6.60            181.3
# 3                    -0.4                 6.61            178.0
# 4                    -0.4                 6.61            174.7
# ..                    ...                  ...              ...
# 67                   -0.3                 4.52             50.0
# 68                   -0.4                 4.47             48.8
# 69                   -0.4                 4.42             47.7
# 70                   -0.3                 4.36             46.4
# 71                                        4.31             45.4
#
#    life_expentancy_(inyears)
# 0                      37.62
# 1                      37.93
# 2                      38.44
# 3                      38.92
# 4                      39.30
# ..                       ...
# 67                     61.99
# 68                     62.34
# 69                     62.69
# 70                     62.23
# 71                     61.66
#
# [72 rows x 12 columns]

# %%
demographic_of_africa_df.rename(columns ={"Index": "Year"}, inplace = True )
demographic_of_africa_df
# Out:
#     Year Mid-year population Live_births  Deaths Natural_change  \
# 0   1950             227 549      10 949   6 063          4 886
# 1   1951             232 484      11 200   6 132          5 068
# 2   1952             237 586      11 448   6 155          5 293
# 3   1953             242 837      11 708   6 188          5 520
# 4   1954             248 245      11 941   6 234          5 708
# ..   ...                 ...         ...     ...            ...
# 67  2017           1 263 334      43 102  10 695         32 408
# 68  2018           1 295 265      43 713  10 763         32 950
# 69  2019           1 327 701      44 295  10 841         33 454
# 70  2020           1 360 677      44 807  11 390         33 417
# 71  2021           1 393 676      45 369  12 038         33 331
#
#    Crude_birth_rate Crude_death_rate Natural_change_(per1000)  \
# 0              48.1             26.6                    4 886
# 1              48.2             26.4                    5 068
# 2              48.2             25.9                    5 293
# 3              48.2             25.5                    5 520
# 4              48.1             25.1                    5 708
# ..              ...              ...                      ...
# 67             34.1              8.5                   32 408
# 68             33.7              8.3                   32 950
# 69             33.3              8.2                   33 454
# 70             32.9              8.4                   33 417
# 71             32.5              8.6                   33 331
#
#    Crude_migration_change Total_fertility_rate infant_mortality  \
# 0                     0.2                 6.59            186.6
# 1                     0.1                 6.59            184.5
# 2                    -0.2                 6.60            181.3
# 3                    -0.4                 6.61            178.0
# 4                    -0.4                 6.61            174.7
# ..                    ...                  ...              ...
# 67                   -0.3                 4.52             50.0
# 68                   -0.4                 4.47             48.8
# 69                   -0.4                 4.42             47.7
# 70                   -0.3                 4.36             46.4
# 71                                        4.31             45.4
#
#    life_expentancy_(inyears)
# 0                      37.62
# 1                      37.93
# 2                      38.44
# 3                      38.92
# 4                      39.30
# ..                       ...
# 67                     61.99
# 68                     62.34
# 69                     62.69
# 70                     62.23
# 71                     61.66
#
# [72 rows x 12 columns]

# %%
# Converting the file to CSV file
demographic_of_africa_df.to_csv('demographic_of_africa.csv', index = False)
